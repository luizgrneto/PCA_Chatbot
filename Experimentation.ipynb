# %%
from litellm import LiteLlm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from litellm import LiteLlm
#
# ImportError: cannot import name 'LiteLlm' from 'litellm' (/home/lgrneto/agent-pca/.venv/lib/python3.13/site-packages/litellm/__init__.py)
